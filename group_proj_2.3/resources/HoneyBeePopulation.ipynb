# %%
import pandas as pd

# %%
all_data = "honeybee_by_state.csv"
df = pd.read_csv(all_data)

# %%
df.head()
# Out:
#   Program  Year        Period  Week Ending Geo Level       State  State ANSI  \
# 0  SURVEY  2019  FIRST OF JAN          NaN     STATE     ALABAMA         1.0
# 1  SURVEY  2019  FIRST OF JAN          NaN     STATE     ARIZONA         4.0
# 2  SURVEY  2019  FIRST OF JAN          NaN     STATE    ARKANSAS         5.0
# 3  SURVEY  2019  FIRST OF JAN          NaN     STATE  CALIFORNIA         6.0
# 4  SURVEY  2019  FIRST OF JAN          NaN     STATE    COLORADO         8.0
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity  \
# 0               0        NaN      HONEY
# ...

# %%
simple_df = df[["Year", "Period", "State", "State ANSI", "Data Item", "Value"]]

# %%
simple_df.head()
# Out:
#    Year        Period       State  State ANSI  \
# 0  2019  FIRST OF JAN     ALABAMA         1.0
# 1  2019  FIRST OF JAN     ARIZONA         4.0
# 2  2019  FIRST OF JAN    ARKANSAS         5.0
# 3  2019  FIRST OF JAN  CALIFORNIA         6.0
# 4  2019  FIRST OF JAN    COLORADO         8.0
#
#                                            Data Item      Value
# 0  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...      5,500
# 1  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...     22,000
# 2  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...     28,000
# 3  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...  1,140,000
# 4  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...      5,000

# %%
market_year_df = simple_df.loc[simple_df["Period"] == "MARKETING YEAR", :]

# %%
market_year_df.head()
# Out:
#      Year          Period       State  State ANSI  \
# 414  2018  MARKETING YEAR     ALABAMA         1.0
# 415  2018  MARKETING YEAR     ARIZONA         4.0
# 416  2018  MARKETING YEAR    ARKANSAS         5.0
# 417  2018  MARKETING YEAR  CALIFORNIA         6.0
# 418  2018  MARKETING YEAR    COLORADO         8.0
#
#                                              Data Item    Value
# 414  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...    6,000
# 415  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...   24,000
# 416  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...   28,000
# 417  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...  335,000
# 418  HONEY, BEE COLONIES - INVENTORY, MEASURED IN C...   31,000

# %%
market_year_df.count()
# Out:
# Year          1396
# Period        1396
# State         1396
# State ANSI    1368
# Data Item     1396
# Value         1396
# dtype: int64

# %%
bee_pop_df = market_year_df[["Year","State","Value"]]

# %%
# Out:
#      Year       State    Value
# 414  2018     ALABAMA    6,000
# 415  2018     ARIZONA   24,000
# 416  2018    ARKANSAS   28,000
# 417  2018  CALIFORNIA  335,000
# 418  2018    COLORADO   31,000

# %%
bee_pop_df = bee_pop_df.rename(columns={"Value":"Population"})

# %%
bee_pop_df.head()
# Out:
#      Year       State Population
# 414  2018     ALABAMA      6,000
# 415  2018     ARIZONA     24,000
# 416  2018    ARKANSAS     28,000
# 417  2018  CALIFORNIA    335,000
# 418  2018    COLORADO     31,000

# %%
bee_pop_df.count()
# Out:
# Year          1396
# State         1396
# Population    1396
# dtype: int64

# %%
bee_pop_df.to_csv('bee_pop_clean.csv')
